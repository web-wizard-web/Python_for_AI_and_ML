# %% [markdown]
# # PANDAS

# %% [markdown]
# **DataFrames**

# %%
import pandas as pd

# %%
df =  pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ["A","B","C"], index =['x','y','z'])
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# informattion of dataframe
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
# to find unique values
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
# shape  of dataframe 
df.shape
# Out:
# (3, 3)

# %%
#size of dataframe
df.size
# Out:
# 9

# %%
coffee = pd.read_csv("coffee.csv")
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet("results.parquet")

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
bios = pd.read_csv("bios.csv")
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# # Accessing data with Pandas

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
# to get random data
coffee.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 1      Monday       Latte          15
# 9      Friday       Latte          35
# 6    Thursday    Espresso          40
# 5   Wednesday       Latte          25
# 8      Friday    Espresso          45
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 7    Thursday       Latte          30

# %% [markdown]
# **Accessing specific part of the DataFrame**

# %%
# loc - allows us to filter by rows and columns of the dataframe loc[#rows, #columns]

coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
# gettinfg rows 0,1,5
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
# getting 2nd row onwards
coffee.loc[2:]
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# upto row 6
coffee.loc[ :6]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40

# %%
# getting specific columns using labels 
coffee.loc[2:9 , ["Day" ,"Units Sold"]]
# Out:
#          Day  Units Sold
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
# iloc - similar to loc but uses indexing instead of labels
coffee.iloc[0:5,[0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %% [markdown]
# **Modifying values using loc**

# %%
coffee.loc[1:3, "Units Sold"] = 10
coffee.head
# Out:
# <bound method NDFrame.head of           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35>

# %%
coffee.iat[0,0]
# Out:
# 'Monday'

# %%
# acessing a single column 
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
# if its a single name you can access it this way 
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %% [markdown]
# # Sorting of Data

# %%
coffee.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# if needed in descending order 
coffee.sort_values("Units Sold", ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
# Units Sold in descending Order and Coffee Typoe in ascending order 
coffee.sort_values(["Units Sold" ,"Coffee Type"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %% [markdown]
# # Iterating through a DataFrame

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row["Units Sold"],row["Coffee Type"])
    print("\n\n\n")
# Out:
# 0
# 25 Espresso
#
#
#
#
# 1
# 10 Latte
#
#
#
#
# 2
# 10 Espresso
#
#
#
#
# 3
# 10 Latte
#
#
#
#
# 4
# 35 Espresso
#
#
#
#
# 5
# 25 Latte
#
#
#
#
# 6
# 40 Espresso
#
#
#
#
# 7
# 30 Latte
#
#
#
#
# 8
# 45 Espresso
#
#
#
#
# 9
# 35 Latte
#
#
#
#
# 10
# 45 Espresso
#
#
#
#
# 11
# 35 Latte
#
#
#
#
# 12
# 45 Espresso
#
#
#
#
# 13
# 35 Latte

# %%
# replace default index by Day as an index
coffee.index= coffee["Day"]

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          10
# Tuesday      Tuesday    Espresso          10
# Tuesday      Tuesday       Latte          10
# Wednesday  Wednesday    Espresso          35

# %%
coffee.loc["Monday"]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          10

# %%
coffee.loc["Monday":"Wednesday"]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          10
# Tuesday      Tuesday    Espresso          10
# Tuesday      Tuesday       Latte          10
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %% [markdown]
# # Filtering Data

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
#Without loc
bios.loc[bios["height_cm"]>200, ["name", "height_cm"]]
# Out:
#                       name  height_cm
# 1080        Bozhil Lozanov      208.0
# 1673      Alexis Rubalcaba      204.0
# 2647         Milan Šrejber      203.0
# 2827    Nik'oloz Deriugini      206.0
# 2832         Elşad Qadaşev      205.0
# ...                    ...        ...
# 143784  Daniel Miklasevich      203.0
# 143833  Garrett Muagututia      205.0
# 143834         Kyle Ensing      201.0
# 143835         Mitch Stahl      203.0
# 143919   Emerson Rodríguez      204.0
#
# [1219 rows x 2 columns]

# %%
bios[bios["height_cm"]>200 ][["name", "height_cm"]]
# Out:
#                       name  height_cm
# 1080        Bozhil Lozanov      208.0
# 1673      Alexis Rubalcaba      204.0
# 2647         Milan Šrejber      203.0
# 2827    Nik'oloz Deriugini      206.0
# 2832         Elşad Qadaşev      205.0
# ...                    ...        ...
# 143784  Daniel Miklasevich      203.0
# 143833  Garrett Muagututia      205.0
# 143834         Kyle Ensing      201.0
# 143835         Mitch Stahl      203.0
# 143919   Emerson Rodríguez      204.0
#
# [1219 rows x 2 columns]

# %%
bios[(bios["height_cm"]>215) & (bios["born_country"]=="USA")][["name","born_country"]]
# Out:
#                     name born_country
# 5781      Tommy Burleson          USA
# 6722    Shaquille O'Neal          USA
# 6937      David Robinson          USA
# 123850    Tyson Chandler          USA

# %%
# Get athlethes having Keith as a name 
bios[bios["name"].str.contains("Keith")].head()
# Out:
#        athlete_id           name   born_date  born_city       born_region  \
# 1897         1907   Keith Hanlon  1966-09-01        NaN               NaN
# 3505         3517  Keith Wallace  1961-03-29    Preston           England
# 6228         6255  Keith Hartley  1940-10-15  Vancouver  British Columbia
# 8898         8946    Keith Mwila  1966-01-01        NaN               NaN
# 12053       12118   Keith Hervey  1898-11-03     Fulham           England
#
#       born_country            NOC  height_cm  weight_kg   died_date
# 1897           NaN        Ireland        NaN        NaN         NaN
# 3505           GBR  Great Britain      165.0       51.0  1999-12-31
# 6228           CAN         Canada      200.0       85.0         NaN
# 8898           NaN         Zambia        NaN        NaN  1993-01-09
# 12053          GBR  Great Britain        NaN        NaN  1973-02-22

# %%
# Keep case = False to neglect case sensitivity
bios[bios["name"].str.contains("keith|Patrick" ,case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
# Find athlethes born in cities that start with a vowel
bios[bios["born_city"].str.contains(r'^[AEIOUaeiou]', na = False)]

# r is raw string prefix in Python . It tells Python not to interpret backlashes as escape
#  sequences in python.

# ^ represrents the startofthe line or word .
# Out:
#         athlete_id                     name   born_date       born_city  \
# 5                6        Nicolas Chatelain  1970-01-13          Amiens
# 10              11  Élie, Comte de Lastours  1874-08-12         Orgeval
# 17              18     Jean-Philippe Gatien  1968-10-16            Alès
# 35              36          Étienne Thobois  1967-09-20          Amiens
# 40              41           Julie Bradbury  1967-02-12          Oxford
# ...            ...                      ...         ...             ...
# 145395      149118             Abbey Murphy  2002-04-14  Evergreen Park
# 145398      149121          Grace Zumwinkle  1999-04-23       Excelsior
# 145405      149128             Brian Cooper  1993-11-01       Anchorage
# 145418      149141              Nick Perbix  1998-06-15       Elk River
# 145427      149150            Jared Shumate  1999-03-06         Atlanta
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
# Find athlethes name that contains exactlt two vowels
bios[bios["name"].str.count(r'[AEIOUaeiou]')==2 ]
# Out:
#         athlete_id           name   born_date    born_city     born_region  \
# 12              13      J. Defert         NaN          NaN             NaN
# 30              31  André Prévost  1875-02-28  Paris VIIIe           Paris
# 68              69      Sam Smith  1971-11-27       Epping         England
# 70              71     Ruth Winch  1870-08-25         Ryde         England
# 73              74     Sky Andrew  1962-03-31       Newham         England
# ...            ...            ...         ...          ...             ...
# 145340      149062     A. J. Hurt  2000-12-05      Truckee      California
# 145349      149072      Kris Horn  1994-04-25     Weymouth   Massachusetts
# 145382      149105  Dylan Walczyk  1993-06-25    Rochester        New York
# 145452      149177     Radek Rýdl  2001-07-15    Jilemnice  Liberecký kraj
# 145483      149210        Feng He  2004-03-31          NaN             NaN
#
# ...

# %%
# to find names having repedated consecutive letters
bios[bios["name"].str.contains(r'(.)\1' , na=False)]

# . captures the character 
# \1 checks if the next character is the same as the captured one
# Out:
# C:\Users\Gayatri\AppData\Local\Temp\ipykernel_15960\1121750093.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bios[bios["name"].str.contains(r'(.)\1' , na=False)]
#         athlete_id                  name   born_date          born_city  \
# 9               10    Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 13              14        Étienne Durand         NaN                NaN
# 17              18  Jean-Philippe Gatien  1968-10-16               Alès
# 20              21         Pierre Hirsch  1900-11-08           Paris Ie
# 28              29       Albert Lippmann         NaN                NaN
# ...            ...                   ...         ...                ...
# 145474      149201     Nadine Hofstetter  1994-10-21             Romoos
# 145488      149215          Shakeel John  2001-07-30         Mount Hope
# ...

# %%
# Find athlethes with names ending with son or sen

bios[bios["name"].str.contains(r'son|sen$' ,case=False ,na=False)]

#$ reprensents the end of word or line
# Out:
#         athlete_id                name   born_date      born_city  \
# 37              38     Helen Aitchison  1881-12-06     Sunderland
# 48              49       Alison Gordon  1962-12-31        Reading
# 92              93         Anne Gibson  1968-10-26       Dumfries
# 107            108      Anders Nielsen  1967-02-24      Cape Town
# 113            114    Julian Robertson  1969-10-09   Peterborough
# ...            ...                 ...         ...            ...
# 145424      149147  Jonathan Gustafson  1997-03-05        Massena
# 145441      149164        Casey Dawson  2000-08-02      Park City
# 145457      149183      Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145461      149188        Kent Johnson  2002-10-18     Port Moody
# 145473      149200      Toms Andersons  1993-11-25           Rīga
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 37               England          GBR  Great Britain        NaN        NaN
# ...

# %%
# Find athlethes born in a year starting with '19'

bios[bios["born_date"].str.contains(r'^19' ,na=False)]
# Out:
#         athlete_id                   name   born_date           born_city  \
# 1                2         Arnaud Boetsch  1969-04-01              Meulan
# 5                6      Nicolas Chatelain  1970-01-13              Amiens
# 6                7          Patrick Chila  1969-11-27         Ris-Orangis
# 7                8           Henri Cochet  1901-12-14        Villeurbanne
# 14              15            Damien Éloi  1969-07-04                Vire
# ...            ...                    ...         ...                 ...
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145496      149223    Valeriya Merkusheva  1999-09-20     Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08              Kotlas
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
# Find athlethes with names that does not contai any vowels 
bios[bios["name"].str.contains(r'^[^AEIOUaeiou]+$', na=False)]

# ^ start of the word 
# [^AEIOUaeiou]+ match characters that are not vowels
# & end of the word
# Out:
#         athlete_id                name   born_date  \
# 3818          3831          György Pál  1939-03-29
# 3831          3844        László Szűcs  1969-10-27
# 5125          5144                Zézé  1966-04-30
# 5764          5787                Bráz  1920-11-25
# 6260          6288         László Hódy  1934-07-10
# 15165        15267        Lê Văn Phươc  1929-10-15
# 21621        21774                Céré         NaN
# 22252        22420        Árpád Bárány  1931-06-24
# 22367        22535       László Széchy  1891-11-18
# 25578        25770         Kálmán Tóth  1944-08-13
# 27325        27525        Gündüz Kılıç  1918-10-29
# 30192        30423           Ödön Téry  1890-07-08
# 31630        31869                  SB  1966-03-16
# 31975        32215           Árpád Pál  1955-02-15
# 33720        33982         Lê Bả Thành  1934-10-12
# 47828        48180           Ödön Gróf  1915-04-15
# 51321        51680        Phạm Thị Phú  1964-03-19
# ...

# %%
# Find athlethes whose name contains an hyphen or an apostrophe
bios[bios["name"].str.contains(r'[-!]' ,na=False)]
# Out:
#         athlete_id                    name   born_date           born_city  \
# 0                1   Jean-François Blanchy  1886-12-12            Bordeaux
# 15              16  Adrien Fauchier-Magnan  1873-11-19         Paris VIIIe
# 17              18    Jean-Philippe Gatien  1968-10-16                Alès
# 33              34  Jean-Pierre Samazeuilh  1891-01-17            Bordeaux
# 36              37    Pierre Verdé-Delisle  1877-05-16       Trie-la-Ville
# ...            ...                     ...         ...                 ...
# 145385      149108     Ashley Cain-Gribble  1995-07-22              Dallas
# 145388      149111          Jean-Luc Baker  1993-10-07             Burnley
# 145470      149197            Lee Chae-Eun  2006-04-11                 NaN
# 145490      149217             Sin Ye-Chan  1995-06-13                 NaN
# 145492      149219   Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
#
# ...

# %%
# find athlethes with names that start and end with the same letter
bios[bios["name"].str.contains(r'^([a-zA-Z]).*\1$' ,case=False,na=False)]

# *\ - matches any character in between 
# \1$ - matched any character in the end
# Out:
# C:\Users\Gayatri\AppData\Local\Temp\ipykernel_15960\2770239208.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bios[bios["name"].str.contains(r'^([a-zA-Z]).*\1$' ,case=False,na=False)]
#         athlete_id                  name   born_date        born_city  \
# 5                6     Nicolas Chatelain  1970-01-13           Amiens
# 121            122           Max Woosnam  1892-09-06        Liverpool
# 164            165        Helen Amankwah  1964-04-13              NaN
# 187            188         Ronald Agénor  1964-11-13            Rabat
# 210            211          Ilona Váradi  1891-08-04         Budapest
# ...            ...                   ...         ...              ...
# 145448      149172   Aleksandra Glazkova  2006-03-15            Miass
# 145450      149174     Anna Shcherbakova  2004-03-28  Moskva (Moscow)
# ...

# %%
# find athlethes with a born_city that has exactly 7 characters 
bios[bios["born_city"].str.contains(r'^[a-z A-Z]{7}$' , na=False)]
# Out:
#         athlete_id                     name   born_date born_city  \
# 10              11  Élie, Comte de Lastours  1874-08-12   Orgeval
# 25              26            Henri Leconte  1963-07-04   Lillers
# 41              42            Gillian Clark  1961-09-02   Baghdad
# 47              48               Sara Gomer  1964-05-13   Torquay
# 48              49            Alison Gordon  1962-12-31   Reading
# ...            ...                      ...         ...       ...
# 145435      149158        Patrick Gasienica  1998-11-28   McHenry
# 145446      149169         Corinne Stoddard  2001-08-15   Seattle
# 145454      149180            Anna Hoffmann  2000-03-28   Madison
# 145456      149182          Sophie Sorschag  1998-11-14   Villach
# 145494      149221            George Wright  1890-07-21   Toronto
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 10           Yvelines          FRA         France        NaN        NaN
# ...

# %%
# Find athlethes with names having 2 or more vowels
bios[bios["name"].str.count(r'[AEIOUaeiou]')>=2]
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...
